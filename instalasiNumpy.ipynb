# %%
import numpy as np

# %%
a = np.array([1,2,3,4])

# %%
b = [1,2,3,4]

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
print(a)
# Out:
# [1 2 3 4]

# %%
print(b)
# Out:
# [1, 2, 3, 4]

# %%
a = a + 1
print(a)
# Out:
# [ 9 10 11 12]

# %%
b = b + [1]
print(b)
# Out:
# [1, 2, 3, 4, 1]
